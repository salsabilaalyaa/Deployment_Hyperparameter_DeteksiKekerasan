# %%
import matplotlib.pyplot as plt

# Data yang diekstrak dari log Anda
val_acc_exp17 = [
 0.5227, 0.6227, 0.8409, 0.8159, 0.7818, 0.8386, 0.8795, 0.8977, 0.8864, 0.8773,
 0.9227, 0.9091, 0.9205, 0.9136, 0.9205, 0.9227, 0.9159, 0.9159, 0.8795, 0.9159,
 0.7818, 0.9273, 0.9273, 0.9023, 0.8727, 0.9205, 0.9295, 0.9273, 0.8818, 0.9227,
 0.9000, 0.9205, 0.9205, 0.9114, 0.9182, 0.9295, 0.9341, 0.9227, 0.9091, 0.9159,
 0.9318, 0.9250, 0.9114, 0.8886, 0.8886, 0.9364, 0.8977, 0.9341, 0.9318, 0.9000]



val_loss_exp17 = [
 0.9954, 0.8933, 0.7201, 0.6902, 0.7005, 0.6304, 0.5363, 0.4726, 0.4694, 0.5352,
 0.4128, 0.4366, 0.4566, 0.4189, 0.4099, 0.4137, 0.4248, 0.3980, 0.5074, 0.4375,
 0.7831, 0.3945, 0.3918, 0.4487, 0.4860, 0.3980, 0.3844, 0.3785, 0.5136, 0.3726,
 0.4222, 0.3683, 0.3601, 0.4016, 0.3514, 0.3452, 0.3674, 0.3404, 0.3717, 0.3476,
 0.3265, 0.3303, 0.3821, 0.4254, 0.4396, 0.3290, 0.3818, 0.3394, 0.3173, 0.4355]



val_acc_exp2 = [
 0.5000, 0.5227, 0.6614, 0.6068, 0.7227, 0.7068, 0.8500, 0.8318, 0.8295, 0.8682,
 0.8455, 0.8614, 0.8545, 0.8182, 0.8386, 0.8727, 0.8455, 0.8773, 0.8864, 0.8864,
 0.8886, 0.8932, 0.8795, 0.8886, 0.8909, 0.8773, 0.8705, 0.8886, 0.9045, 0.8886,
 0.8864, 0.8955, 0.8614, 0.8727, 0.8977, 0.8864, 0.9091, 0.9045, 0.8909, 0.8955,
 0.8864, 0.8932, 0.8864, 0.8455, 0.8955, 0.8864, 0.8773, 0.8750, 0.8045, 0.8727]



val_loss_exp2 = [
 1.0495, 0.9490, 0.8392, 0.8548, 0.7908, 0.8374, 0.6150, 0.6119, 0.6049, 0.5292,
 0.5829, 0.5256, 0.5531, 0.5920, 0.5420, 0.5051, 0.5136, 0.4561, 0.4264, 0.4483,
 0.4444, 0.4163, 0.4434, 0.4121, 0.4119, 0.4505, 0.4644, 0.4354, 0.3983, 0.3968,
 0.4274, 0.3918, 0.4591, 0.4163, 0.3955, 0.4178, 0.3682, 0.3868, 0.3823, 0.3720,
 0.3884, 0.3788, 0.3841, 0.4678, 0.3544, 0.4016, 0.4113, 0.4225, 0.5437, 0.4468]



# Ambil panjang yang paling pendek agar plot tidak error jika panjang list berbeda
max_epochs = min(len(val_acc_exp2), len(val_acc_exp17))
epoch_range = range(1, max_epochs + 1)

# --- Gambar 4.1: Perbandingan Akurasi Validasi (MCLAHE vs. Tanpa MCLAHE) ---
plt.figure(figsize=(10, 6))
plt.plot(epoch_range, val_acc_exp17[:max_epochs], label='Dengan MCLAHE (Eksperimen No. 17)', color='blue')
plt.plot(epoch_range, val_acc_exp2[:max_epochs], label='Tanpa MCLAHE (Eksperimen No. 2)', color='red')
plt.title('Perbandingan Akurasi Validasi Model (MCLAHE vs. Tanpa MCLAHE)', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Akurasi Validasi', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# --- Gambar 4.2: Perbandingan Loss Validasi (MCLAHE vs. Tanpa MCLAHE) ---
plt.figure(figsize=(10, 6))
plt.plot(epoch_range, val_acc_exp17[:max_epochs], label='Dengan MCLAHE (Eksperimen No. 17)', color='blue')
plt.plot(epoch_range, val_acc_exp2[:max_epochs], label='Tanpa MCLAHE (Eksperimen No. 2)', color='red')
plt.title('Perbandingan Loss Validasi Model (MCLAHE vs. Tanpa MCLAHE)', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss Validasi', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
